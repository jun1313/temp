# %%
from bs4 import BeautifulSoup     
from selenium import webdriver
import urllib.request
import urllib
import time
import sys
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import os
import random
import requests
query_txt = input('크롤링할 키워드는 무엇입니까?:')
num = input('크롤링 할 건수는 몇개입니까?:')
f_dir = input('파일이 저장될 경로만 쓰시오(예: /Users/jun-mac/final/image/): ')
path = "/Users/jun-mac/py_temp/chromedriver.exec"
driver = webdriver.Chrome(path)
driver.get("https://www.google.co.kr/imghp?hl=ko&authuser=0&ogbl")
driver.find_element(By.ID,'APjFqb').click()
element =driver.find_element(By.ID,'APjFqb')
element.send_keys(query_txt)
driver.find_element(By.CLASS_NAME, 'Tg7LZd').click()
os.chdir(f_dir)
file_no = 0                                
count = 1
img_srcs=[]
full_html = driver.page_source
soup = BeautifulSoup(full_html, 'html.parser')
img_src = soup.find('div','islrc').find_all('img')
#이미지 정보
for i in img_src :
    for test in i :
        temp=test['src']
        img_srcs.append(temp)
        #dload.save(temp, f'image/{count}.jpg') 
        count += 1
        if count==num:
            break

test='/Users/jun-mac/final/image/1.jpg'
for i in range(0,len(img_srcs)) :
        try:
            #temp_f='f_dir'+str(fil
            #urllib.request.urlretrieve(img_srcs[i],str(file_no)+'.jpg')#실행안됨
            #실행됨
            filename=str(file_no)+'.jpg'
            url =img_srcs[i]
            r = requests.get(url)
            with open(f_dir+filename,"wb") as outfile:
                outfile.write(r.content)
            #urllib.request.urlretrieve(img_srcs[i],str(temp_f)+'.jpg')
            file_no += 1
            if file_no==num:
                break
        except:
                #gif제외
                print('jpg가 아님')
                continue
